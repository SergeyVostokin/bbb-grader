# %% [markdown]
# **Шаг 1.** Скопируйте список группы в файл ***"список группы.txt"***

# %% [markdown]
# **Шаг 2.** Скопируйте список присутсвующих в файл ***"список присутсвующих.txt"***

# %% [markdown]
# **Шаг 3.** Вывести *распознанные пары* вида ***"ФИО в списке группы" -- "ФИО в списе присутсвующих"***

# %%
stars = []
points = []
with open("список группы.txt", "r",encoding= 'UTF-8') as groupF:
    with open("список присутсвующих.txt","r",encoding= 'UTF-8') as presF:
        num = groupF.readline().strip()
        print(num)
        stars.append(num)
        points.append(num)
        presLine = ""
        while(not presLine.__contains__("Сортировать по имени:")):
            presLine = presF.readline()
        presLine = presF.readline()
        presLine = presLine[5:]
        groupLine = groupF.readline()
        while(groupLine!=""):
            if(groupLine=="\n"):
                groupLine = groupF.readline().strip()
                print("\n"+groupLine)
                stars.append(groupLine)
                points.append(groupLine)
                groupLine = groupF.readline().strip()
            presLine = presLine.strip()
            groupLine = groupLine.strip()
            if(groupLine.__contains__(presLine)):
                stars.append("*")
                points.append("+")
                print(presLine, "--", groupLine)
                presLine = presF.readline()
                presLine = presLine[5:]
                groupLine = groupF.readline()
            else:
                print(groupLine," -- ", "empty")
                stars.append(" ")
                points.append("о")
                groupLine = groupF.readline()
    presF.close()
groupF.close()
# Out:
# 6302:
# Артемьев Артем Артемьевич  --  empty
# Белоусов Антон -- Белоусов Антон Максимович
# Бережко Светлана -- Бережко Светлана Юрьевна
# Булатова Диляра -- Булатова Диляра Равилевна
# Виншель Эдуард -- Виншель Эдуард Александрович
# Дмитриев Кирилл -- Дмитриев Кирилл Дмитриевич
# Дусаев Ильнур Рафикович  --  empty
# Егорова Анастасия -- Егорова Анастасия Николаевна
# Золотарев Иван -- Золотарев Иван Александрович
# Ким Никита -- Ким Никита Александрович
# Клюшкин Сергей -- Клюшкин Сергей Дмитриевич
# Кубанов Кирилл Валерьевич  --  empty
# Лукашев Андрей -- Лукашев Андрей Валерьевич
# Мельникова Алена -- Мельникова Алена Александровна
# Осипов Алексей -- Осипов Алексей Романович
# Рахметов Илья -- Рахметов Илья Павлович
# Романенко Мария -- Романенко Мария Владимировна
# Самедов Дмитрий -- Самедов Дмитрий Магомедалиевич
# Суслов Игорь Сергеевич  --  empty
# Терехов Сергей -- Терехов Сергей Юрьевич
# Тюлюнова Екатерина Александровна  --  empty
# Ханов Михаил -- Ханов Михаил Алексеевич
# Христич Светлана -- Христич Светлана Витальевна
# Шайдулина Диана Васимовна  --  empty
# Шкайдуров Егор Александрович  --  empty
# Шулаев Глеб Васильевич  --  empty
# Захарова Анастасия Олеговна  --  empty
#
# 6303:
# Алексеев Максим -- Алексеев Максим Владимирович
# Лобачев Александр Алексеевич  --  empty

# %% [markdown]
# **Шаг 4.** Вывести *нераспознанные* записи ***"ФИО в списе присутсвующих"***

# %%
print("\nНераспознанные пользователи:")
with open("список присутсвующих.txt","r",encoding= 'UTF-8') as presF:
    presLine = presF.readline()
    while (not presLine.__contains__("Сортировать по имени:")):
        presLine = presF.readline()
    presLine = presF.readline()
    while not presLine.__contains__("Сортировать по фамилии:"):
        presLine = presLine.strip()
        if not presLine[:4].isdigit():
            print(presLine)
        else:
            with open("список группы.txt", "r", encoding='UTF-8') as groupF:
                presLine = presLine[5:]
                groupLine = groupF.readline()
                while(groupLine != ""):
                    if(groupLine.__contains__(presLine)):
                        break;
                    groupLine = groupF.readline()
                if(groupLine==""):
                    print(presLine)
            groupF.close()
        presLine = presF.readline()
# Out:
# Нераспознанные пользователи:
# Востокин Сергей Владимирович

# %% [markdown]
# **Шаг 5.** Внести ручные коррективы в список присутсвующих, повторить **шаги 3,4**

# %% [markdown]
# **Шаг 6.** Вывести столбик из отметок **\*** для ручного копирования в электронную таблицу

# %%
with open("список звёзд.txt",'w',encoding='UTF-8') as outF:
    for i in range(stars.__len__()):
        print(stars[i])
        outF.write(stars[i]+"\n")
    print("---------")
    outF.write("-----------------Конец------------------------")
outF.close()
# Out:
# 6302:
#
# *
# *
# *
# *
# *
#
# *
# *
# *
# *
#
# *
# *
# *
# *
# *
# *
#
# *
#
# *
# *
#
#
#
#
# 6303:
# *
# *
# *
# *
# *
# *
#
#
#
# *
#
#
# *
# *
# *
# *
# *
# *
# *
# *
#
# *
#
# *
# *
#
# *
# *
# 6304:
#
# *
# *
#
#
# *
# *
# *
# *
# *
# *
# *
#
# *
# *
#
# *
# *
# *
# *
#
# *
#
#
#
# *
#
#
#
# ---------

# %% [markdown]
# **Шаг 7**. Вывести список из пар: отметка  **\[+\]** или **\[o\]** -- ФИО для ручного заполения ведомости в ***cabinet.ssau.ru***

# %%
with open("список ведомости.txt",'w',encoding='UTF-8') as outF:
    for i in range(points.__len__()):
        print(points[i])
        outF.write(points[i]+"\n")
    print("------------------------------")
    outF.write("------------------------------")
outF.close()
# Out:
# 6302:
# о
# +
# +
# +
# +
# +
# о
# +
# +
# +
# +
# о
# +
# +
# +
# +
# +
# +
# о
# +
# о
# +
# +
# о
# о
# о
# о
# 6303:
# +
# +
# +
# +
# +
# +
# о
# о
# о
# +
# о
# о
# +
# +
# +
# +
# +
# +
# +
# +
# о
# +
# о
# +
# +
# о
# +
# +
# 6304:
# о
# +
# +
# о
# о
# +
# +
# +
# +
# +
# +
# +
# о
# +
# +
# о
# +
# +
# +
# +
# о
# +
# о
# о
# о
# +
# о
# о
# о
# ------------------------------
